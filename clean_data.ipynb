# %%
import pandas as pd

# %%
load_file = "winemag-data_first150k.csv"
data_first_df = pd.read_csv(load_file)
data_first_df.head()
# Out:
#    Unnamed: 0 country                                        description  \
# 0           0      US  This tremendous 100% varietal wine hails from ...
# 1           1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2           2      US  Mac Watson honors the memory of a wine once ma...
# 3           3      US  This spent 20 months in 30% new French oak, an...
# 4           4  France  This is the top wine from La Bégude, named aft...
#
#                             designation  points  price        province  \
# 0                     Martha's Vineyard      96  235.0      California
# 1  Carodorum Selección Especial Reserva      96  110.0  Northern Spain
# 2         Special Selected Late Harvest      96   90.0      California
# 3                               Reserve      96   65.0          Oregon
# 4                            La Brûlade      95   66.0        Provence
#
#             region_1           region_2             variety  \
# ...

# %%
load_file_2 = "winemag-data-130k-v2.csv"
data_second_df = pd.read_csv(load_file_2)
data_second_df.head()
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# ...

# %%
for columns in data_second_df.columns:
    print(columns)
# Out:
# Unnamed: 0
# country
# description
# designation
# points
# price
# province
# region_1
# region_2
# taster_name
# taster_twitter_handle
# title
# variety
# winery

# %%
del data_second_df['Unnamed: 0']

# %%
print(data_second_df.columns)
# Out:
# Index(['country', 'description', 'designation', 'points', 'price', 'province',
#        'region_1', 'region_2', 'taster_name', 'taster_twitter_handle', 'title',
#        'variety', 'winery'],
#       dtype='object')

# %%
data_second_df.head()
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# ...

# %%
# (data_second_df.groupby('country')['price']).style.format('${0:,.2f}')
# def format(x/1000):
#         return "${0:,.2f}".format(x)
# data_second_df['price'] = data_second_df['price'].apply(lambda x: f"${x/1000:.1f}k")

# def format(x):
#         return "${0:,.2f}".format(x)
# data_second_df['price'] = data_second_df['price'].apply(lambda x: f"${x:.1f}k")

def format(x):
        return "${0:,.2f}".format(x)
data_second_df['price'] = data_second_df['price'].apply(lambda x: f"${x:.1f}")

# %%
data_second_df.head()
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87   $nan  Sicily & Sardinia
# 1                            Avidagos      87  $15.0              Douro
# 2                                 NaN      87  $14.0             Oregon
# 3                Reserve Late Harvest      87  $13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87  $65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# ...

# %%
sorted_df = data_second_df.sort_values(['price'], ascending=False)

# %%
sorted_df.dropna(subset=['price'])
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 41275     France  A rich wine with spice and red fruits, the tan...
# 106395    France  Spicy new wood flavors dominate this otherwise...
# 106402    France  This is a ripe wine with spice, juicy red frui...
# 106403    France  This is a perfumed, new wood-flavored wine. It...
# ...          ...                                                ...
# 95268      Chile  Scratchy rhubarb aromas run tart and weedy. Th...
# 13176         US  An appealing wine with notes of herbs, goosebe...
# 60510     France  This wine has soft apple and ripe pear flavors...
# 95290   Portugal  Initially tannic, this concentrated wine shows...
# 15164      Chile  Composed on the nose, this has a berry aroma a...
#
#                             designation  points  price           province  \
# 0                          Vulkà Bianco      87   $nan  Sicily & Sardinia
# ...

# %%
frames =  [data_first_df, data_second_df]
result = pd.concat(frames, join='outer')

# %%
result.head()
# Out:
#    Unnamed: 0 country                                        description  \
# 0         0.0      US  This tremendous 100% varietal wine hails from ...
# 1         1.0   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2         2.0      US  Mac Watson honors the memory of a wine once ma...
# 3         3.0      US  This spent 20 months in 30% new French oak, an...
# 4         4.0  France  This is the top wine from La Bégude, named aft...
#
#                             designation  points price        province  \
# 0                     Martha's Vineyard      96   235      California
# 1  Carodorum Selección Especial Reserva      96   110  Northern Spain
# 2         Special Selected Late Harvest      96    90      California
# 3                               Reserve      96    65          Oregon
# 4                            La Brûlade      95    66        Provence
#
#             region_1           region_2             variety  \
# ...

# %%
len(result['description'])
# Out:
# 280901

# %%
result_drop = result.dropna(subset=['description'])

# %%
len(result_drop['description'])
# Out:
# 280901

# %%
len(data_first_df['description'])
# Out:
# 150930

# %%
len(data_second_df['description'])
# Out:
# 129971

# %%
len(result)
# Out:
# 280901
