# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as st

# %%
load_file = "winemag-data_first150k.csv"
data_first_df = pd.read_csv(load_file)
data_first_df.head()
# Out:
#    Unnamed: 0 country                                        description  \
# 0           0      US  This tremendous 100% varietal wine hails from ...
# 1           1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2           2      US  Mac Watson honors the memory of a wine once ma...
# 3           3      US  This spent 20 months in 30% new French oak, an...
# 4           4  France  This is the top wine from La Bégude, named aft...
#
#                             designation  points  price        province  \
# 0                     Martha's Vineyard      96  235.0      California
# 1  Carodorum Selección Especial Reserva      96  110.0  Northern Spain
# 2         Special Selected Late Harvest      96   90.0      California
# 3                               Reserve      96   65.0          Oregon
# 4                            La Brûlade      95   66.0        Provence
#
#             region_1           region_2             variety  \
# ...

# %%
load_file_2 = "winemag-data-130k-v2.csv"
data_second_df = pd.read_csv(load_file_2)
data_second_df.head()
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# ...

# %%
for columns in data_second_df.columns:
    print(columns)
# Out:
# Unnamed: 0
# country
# description
# designation
# points
# price
# province
# region_1
# region_2
# taster_name
# taster_twitter_handle
# title
# variety
# winery

# %%
del data_second_df['taster_name']

# %%
del data_second_df['taster_twitter_handle']

# %%
del data_second_df['title']

# %%
for columns in data_first_df.columns:
    print(columns)
# Out:
# Unnamed: 0
# country
# description
# designation
# points
# price
# province
# region_1
# region_2
# variety
# winery

# %%
df_merge = pd.merge(data_first_df, data_second_df, how = "outer", on = list(data_second_df.columns))

# %%
df_merge.head()
# Out:
#    Unnamed: 0 country                                        description  \
# 0           0      US  This tremendous 100% varietal wine hails from ...
# 1           1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2           2      US  Mac Watson honors the memory of a wine once ma...
# 3           3      US  This spent 20 months in 30% new French oak, an...
# 4           4  France  This is the top wine from La Bégude, named aft...
#
#                             designation  points  price        province  \
# 0                     Martha's Vineyard      96  235.0      California
# 1  Carodorum Selección Especial Reserva      96  110.0  Northern Spain
# 2         Special Selected Late Harvest      96   90.0      California
# 3                               Reserve      96   65.0          Oregon
# 4                            La Brûlade      95   66.0        Provence
#
#             region_1           region_2             variety  \
# ...

# %%
del df_merge['Unnamed: 0']

# %%
print(df_merge.columns)
# Out:
# Index(['country', 'description', 'designation', 'points', 'price', 'province',
#        'region_1', 'region_2', 'variety', 'winery'],
#       dtype='object')

# %%
# (data_second_df.groupby('country')['price']).style.format('${0:,.2f}')
# def format(x/1000):
#         return "${0:,.2f}".format(x)
# data_second_df['price'] = data_second_df['price'].apply(lambda x: f"${x/1000:.1f}k")

# def format(x):
#         return "${0:,.2f}".format(x)
# data_second_df['price'] = data_second_df['price'].apply(lambda x: f"${x:.1f}k")

def format(x):
        return "${0:,.2f}".format(x)
df_merge['price'] = df_merge['price'].apply(lambda x: f"${x:.1f}")

# %%
df_merge.head()
# Out:
#   country                                        description  \
# 0      US  This tremendous 100% varietal wine hails from ...
# 1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2      US  Mac Watson honors the memory of a wine once ma...
# 3      US  This spent 20 months in 30% new French oak, an...
# 4  France  This is the top wine from La Bégude, named aft...
#
#                             designation  points   price        province  \
# 0                     Martha's Vineyard      96  $235.0      California
# 1  Carodorum Selección Especial Reserva      96  $110.0  Northern Spain
# 2         Special Selected Late Harvest      96   $90.0      California
# 3                               Reserve      96   $65.0          Oregon
# 4                            La Brûlade      95   $66.0        Provence
#
#             region_1           region_2             variety  \
# 0        Napa Valley               Napa  Cabernet Sauvignon
# ...

# %%
df_merge.describe()
# Out:
#               points
# count  280900.000000
# mean       88.146938
# std         3.151533
# min        80.000000
# 25%        86.000000
# 50%        88.000000
# 75%        90.000000
# max       100.000000

# %%
df_merge = df_merge.replace('',np.nan)
df_merge = df_merge.dropna()

# %%
df_merge.describe()
# Out:
#              points
# count  73659.000000
# mean      88.692773
# std        3.299062
# min       80.000000
# 25%       86.000000
# 50%       89.000000
# 75%       91.000000
# max      100.000000

# %%
sorted_df = df_merge.sort_values(['price'], ascending=False)
sorted_df.tail()
# Out:
#        country                                        description  \
# 138267      US  Frankly sweet, this Riesling, made only from c...
# 260328      US  These vineyards seem to have been selected for...
# 74708       US  Dry, but not entirely, with a honeyed edge tha...
# 63921       US  Half Merlot, half Cab (mostly Franc) this “eve...
# 178874      US  A good deal for a dry rosé that's almost red l...
#
#                designation  points  price    province              region_1  \
# 138267   Vintner's Reserve      83  $10.0  California            California
# 260328  Selected Vineyards      80  $10.0  California         Central Coast
# 74708            Extra Dry      85  $10.0  California            California
# 63921                  MC2      87  $10.0  Washington  Columbia Valley (WA)
# 178874             2 Jakes      85  $10.0  California            California
#
#                 region_2          variety                   winery
# ...

# %%
# graph?
x = df_merge['price']
y = df_merge['points']

# correlation = st.pearsonr(x,y)


plt.scatter(x,y)

# %%
df_merge['points'].dtypes
# Out:
# dtype('int64')

# %%
df_merge['price'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-e721a2817e4f> in <module>
# ----> 1 df_merge['price'].astype(int)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5544         else:
#    5545             # else, only a single dtype is given
# -> 5546             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors,)
#    5547             return self._constructor(new_data).__finalize__(self, method="astype")
#    5548
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     593         self, dtype, copy: bool = False, errors: str = "raise"
#     594     ) -> "BlockManager":
# --> 595         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     596
#     597     def convert(
#
# ...

# %%
# sorted_df.dropna(subset=['price'])

# %%
# frames =  [data_first_df, data_second_df]
# result = pd.concat(frames, join='outer')

# %%
# result.head()

# %%
len(result['description'])

# %%
result_drop = result.dropna(subset=['description'])

# %%
len(result_drop['description'])

# %%
len(data_first_df['description'])

# %%
len(data_second_df['description'])

# %%
len(result)
