# %%
import pandas as pd

# %%
df = pd.read_csv("winemag-data-130k-v2.csv")
df.head()
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# ...

# %%
df.describe()
# Out:
#           Unnamed: 0         points          price
# count  129971.000000  129971.000000  120975.000000
# mean    64985.000000      88.447138      35.363389
# std     37519.540256       3.039730      41.022218
# min         0.000000      80.000000       4.000000
# 25%     32492.500000      86.000000      17.000000
# 50%     64985.000000      88.000000      25.000000
# 75%     97477.500000      91.000000      42.000000
# max    129970.000000     100.000000    3300.000000

# %%
df.loc[df["price"] > 3000]
# Out:
#        Unnamed: 0 country                                        description  \
# 80290       80290  France  This ripe wine shows plenty of blackberry frui...
#
#       designation  points   price  province region_1 region_2 taster_name  \
# 80290         NaN      88  3300.0  Bordeaux    Médoc      NaN  Roger Voss
#
#       taster_twitter_handle                                 title  \
# 80290            @vossroger  Château les Ormes Sorbet 2013  Médoc
#
#                         variety                    winery
# 80290  Bordeaux-style Red Blend  Château les Ormes Sorbet

# %%
df.count()
# Out:
# Unnamed: 0               129971
# country                  129908
# description              129971
# designation               92506
# points                   129971
# price                    120975
# province                 129908
# region_1                 108724
# region_2                  50511
# taster_name              103727
# taster_twitter_handle     98758
# title                    129971
# variety                  129970
# winery                   129971
# dtype: int64

# %%
df150 = pd.read_csv("winemag-data_first150k.csv")

# %%
df150.head()
# Out:
#    Unnamed: 0 country                                        description  \
# 0           0      US  This tremendous 100% varietal wine hails from ...
# 1           1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2           2      US  Mac Watson honors the memory of a wine once ma...
# 3           3      US  This spent 20 months in 30% new French oak, an...
# 4           4  France  This is the top wine from La Bégude, named aft...
#
#                             designation  points  price        province  \
# 0                     Martha's Vineyard      96  235.0      California
# 1  Carodorum Selección Especial Reserva      96  110.0  Northern Spain
# 2         Special Selected Late Harvest      96   90.0      California
# 3                               Reserve      96   65.0          Oregon
# 4                            La Brûlade      95   66.0        Provence
#
#             region_1           region_2             variety  \
# ...

# %%
df.head()
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# ...

# %%
df150.count()
# Out:
# Unnamed: 0     150930
# country        150925
# description    150930
# designation    105195
# points         150930
# price          137235
# province       150925
# region_1       125870
# region_2        60953
# variety        150930
# winery         150930
# dtype: int64

# %%
df.count()
# Out:
# Unnamed: 0               129971
# country                  129908
# description              129971
# designation               92506
# points                   129971
# price                    120975
# province                 129908
# region_1                 108724
# region_2                  50511
# taster_name              103727
# taster_twitter_handle     98758
# title                    129971
# variety                  129970
# winery                   129971
# dtype: int64

# %%
for thing in df.head().iterrows():
    region_1 = str(list(thing)[1][7])
    region_2 = str(list(thing)[1][8])
    print(region_1)
    print(region_2)

    if region_2 == "nan":
        if region_1 == "nan":
            region = "NA"
        else:
            region = region_1
    else:
        region = (f"{list(thing)[1][7]}, {list(thing)[1][8]}")

    print(region)
    print("--------------------")
# Out:
# Etna
# nan
# Etna
# --------------------
# nan
# nan
# NA
# --------------------
# Willamette Valley
# Willamette Valley
# Willamette Valley, Willamette Valley
# --------------------
# Lake Michigan Shore
# nan
# Lake Michigan Shore
# --------------------
# Willamette Valley
# Willamette Valley
# Willamette Valley, Willamette Valley
# --------------------

# %%
df.loc[df["points"] == 100].loc[df["province"] == "Bordeaux"]
# Out:
#         Unnamed: 0 country                                        description  \
# 58352        58352  France  This is a magnificently solid wine, initially ...
# 111753      111753  France  Almost black in color, this stunning wine is g...
# 111755      111755  France  This is the finest Cheval Blanc for many years...
# 111756      111756  France  A hugely powerful wine, full of dark, brooding...
# 122935      122935  France  Full of ripe fruit, opulent and concentrated, ...
#
#        designation  points   price  province        region_1 region_2  \
# 58352          NaN     100   150.0  Bordeaux    Saint-Julien      NaN
# 111753         NaN     100  1500.0  Bordeaux        Pauillac      NaN
# 111755         NaN     100  1500.0  Bordeaux   Saint-Émilion      NaN
# 111756         NaN     100   359.0  Bordeaux    Saint-Julien      NaN
# 122935         NaN     100   848.0  Bordeaux  Pessac-Léognan      NaN
#
#        taster_name taster_twitter_handle  \
# ...

# %%
df150.loc[df150["points"] == 100].loc[df150["province"] == "Bordeaux"]
# Out:
#       Unnamed: 0 country                                        description  \
# 2145        2145  France  Full of ripe fruit, opulent and concentrated, ...
#
#      designation  points  price  province        region_1 region_2  \
# 2145         NaN     100  848.0  Bordeaux  Pessac-Léognan      NaN
#
#                          variety              winery
# 2145  Bordeaux-style White Blend  Château Haut-Brion

# %%
list(df150.columns)
# Out:
# ['Unnamed: 0',
#  'country',
#  'description',
#  'designation',
#  'points',
#  'price',
#  'province',
#  'region_1',
#  'region_2',
#  'variety',
#  'winery']

# %%
merge_df = pd.merge(df, df150, how = "outer", on = list(df150.columns))

# %%
len(merge_df)
# Out:
# 280900

# %%
combined_df = merge_df.drop_duplicates(subset = "description", keep = "first")

# %%
combined_df.describe()
# Out:
#           Unnamed: 0         points          price
# count  169430.000000  169430.000000  156629.000000
# mean    65913.604332      88.243162      34.677550
# std     39002.770124       3.144880      39.942783
# min         0.000000      80.000000       4.000000
# 25%     32721.250000      86.000000      16.000000
# 50%     63974.500000      88.000000      25.000000
# 75%     97788.000000      90.000000      40.000000
# max    149639.000000     100.000000    3300.000000

# %%
combined_df.head()
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# ...

# %%
combined_df.count()
# Out:
# Unnamed: 0               169430
# country                  169370
# description              169430
# designation              119363
# points                   169430
# price                    156629
# province                 169370
# region_1                 141492
# region_2                  66784
# taster_name               95043
# taster_twitter_handle     90514
# title                    119955
# variety                  169429
# winery                   169430
# dtype: int64

# %%
combined_df.duplicated(subset = "description").value_counts()
# Out:
# False    169430
# dtype: int64

# %%
merge_df.duplicated(subset = "description").value_counts()
# Out:
# False    169430
# True     111470
# dtype: int64

# %%
df150.duplicated(subset = "description").value_counts()
# Out:
# False    97821
# True     53109
# dtype: int64

# %%
df.duplicated(subset = "description").value_counts()
# Out:
# False    119955
# True      10016
# dtype: int64

# %%
len(df["description"].unique())
# Out:
# 119955
